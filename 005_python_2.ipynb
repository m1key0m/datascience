# %%
n = int(input())

for i in range(1, n + 1):

    print(i)

    print("")
    


    # increasing part
#    inc = ''.join(str(x) for x in range(1, i + 1))
    # decreasing part
#    dec = ''.join(str(x) for x in range(i - 1, 0, -1))
#    print(inc + dec)
# Out:
# 1
# 2
# 3
# 4
# 5
