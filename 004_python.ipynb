# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    if (a >= 1 and a <= 10 ** 10) and (a >= 1 and a <= 10 ** 10):
        print(a+b)
        print(a-b)
        print(a*b)
    else:
        print('Try again')
        exit (0)
# Out:
# 5
# 1
# 6

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)
# Out:
# 1
# 1.3333333333333333

# %%
import math
import os
import random
import re
import sys

if __name__ == '__main__':
    n = int(input().strip())
    if (n % 2 == 0):
        if ( n >= 2 and n <= 5):
            print('Not Weird')
        if ( n >= 6 and n <= 20):
            print('Weird')
        if ( n > 20 ):
            print('Not Weird')
    else:
        print('Weird')
# Out:
# Weird

# %%
if __name__ == '__main__':
    n = int(input())
    if ( n >= 1 and n <= 20):
        for num in range(n):
            print (num**2)
# Out:
# 0
# 1
# 4
# 9
# 16
